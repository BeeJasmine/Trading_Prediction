# %%
import math
import pandas_datareader as web 
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight') 


df2 = web.DataReader('MSFT', data_source='yahoo', start='2015-01-01', end='2020-09-03')
# Out:
# Using TensorFlow backend.

# %%
df2
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2015-01-02   47.419998   46.540001   46.660000   46.759998  27913900.0
# 2015-01-05   46.730000   46.250000   46.369999   46.330002  39673900.0
# 2015-01-06   46.750000   45.540001   46.380001   45.650002  36447900.0
# 2015-01-07   46.459999   45.490002   45.980000   46.230000  29114100.0
# 2015-01-08   47.750000   46.720001   46.750000   47.590000  29645200.0
# ...                ...         ...         ...         ...         ...
# 2020-08-28  230.639999  226.580002  228.179993  228.910004  26292900.0
# 2020-08-31  228.699997  224.309998  227.000000  225.529999  28774200.0
# 2020-09-01  227.449997  224.429993  225.509995  227.270004  25791200.0
# 2020-09-02  232.860001  227.350006  227.970001  231.649994  34080800.0
# 2020-09-03  229.309998  214.960007  229.270004  217.300003  58400300.0
#
#              Adj Close
# Date
# 2015-01-02   41.647892
# 2015-01-05   41.264908
# 2015-01-06   40.659245
# 2015-01-07   41.175831
# 2015-01-08   42.387146
# ...                ...
# 2020-08-28  228.910004
# 2020-08-31  225.529999
# 2020-09-01  227.270004
# 2020-09-02  231.649994
# 2020-09-03  217.300003
#
# [1429 rows x 6 columns]

# %%
#get number of rows & columns
df.shape
# Out:
# (1429, 6)

# %%
#visualize
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
#new df with df[close]
close_data = df.filter(['Close'])

#convert to np array
close_dataset=close_data.values

#number of rows to train model on
training_data_len = math.ceil(len(close_dataset) * .8) #pour entrainer sur 80% de notre data

training_data_len
# Out:
# 1144

# %%
#data scaling
scaler = MinMaxScaler(feature_range=(0,1))
scaled_close_data = scaler.fit_transform(close_dataset)

scaled_close_data
# Out:
# array([[0.04254224],
#        [0.03564229],
#        [0.0356647 ],
#        ...,
#        [1.        ],
#        [0.9750885 ],
#        [0.88081907]])

# %%
# create scaled training dataset
train_close_data = scaled_close_data[0:training_data_len, :]

#split the data into x_train and y_train sets
x_train = []
y_train = []

for i in range(60, len(train_close_data)):
    x_train.append(train_close_data[i-60:i, 0])
    y_train.append(train_close_data[i,0]) #60 values from index 0 to 59
    
    if i <= 61:
        print(x_train)
        print(y_train)
        print()
# Out:
# [array([0.04254224, 0.03564229, 0.0356647 , 0.03900265, 0.04827726,
#        0.0485461 , 0.04236302, 0.04453606, 0.04359516, 0.03691923,
#        0.03505982, 0.04117569, 0.0430351 , 0.04941979, 0.05071914,
#        0.05098796, 0.04211659, 0.05593889, 0.06398138, 0.06008336,
#        0.0633765 , 0.06342132, 0.06545993, 0.06631123, 0.06404858,
#        0.06581838, 0.07097093, 0.07737803, 0.08091761, 0.08230657,
#        0.08398675, 0.08598057, 0.0853757 , 0.08772796, 0.09556881,
#        0.09370941, 0.08613737, 0.08978898, 0.08539812, 0.08680945,
#        0.08741433, 0.08557731, 0.08080561, 0.08123125, 0.08244098,
#        0.07654915, 0.07146378, 0.07641472, 0.07448811, 0.07753484,
#        0.08221696, 0.08542051, 0.08324747, 0.07966308, 0.0825978 ,
#        0.08143288, 0.07401766, 0.07594427, 0.07372643, 0.080716  ])]
# [0.07636992231957127]
#
# [array([0.04254224, 0.03564229, 0.0356647 , 0.03900265, 0.04827726,
#        0.0485461 , 0.04236302, 0.04453606, 0.04359516, 0.03691923,
#        0.03505982, 0.04117569, 0.0430351 , 0.04941979, 0.05071914,
#        0.05098796, 0.04211659, 0.05593889, 0.06398138, 0.06008336,
#        0.0633765 , 0.06342132, 0.06545993, 0.06631123, 0.06404858,
#        0.06581838, 0.07097093, 0.07737803, 0.08091761, 0.08230657,
#        0.08398675, 0.08598057, 0.0853757 , 0.08772796, 0.09556881,
#        0.09370941, 0.08613737, 0.08978898, 0.08539812, 0.08680945,
#        0.08741433, 0.08557731, 0.08080561, 0.08123125, 0.08244098,
#        0.07654915, 0.07146378, 0.07641472, 0.07448811, 0.07753484,
#        0.08221696, 0.08542051, 0.08324747, 0.07966308, 0.0825978 ,
#        0.08143288, 0.07401766, 0.07594427, 0.07372643, 0.080716  ]), array([0.03564229, 0.0356647 , 0.03900265, 0.04827726, 0.0485461 ,
#        0.04236302, 0.04453606, 0.04359516, 0.03691923, 0.03505982,
#        0.04117569, 0.0430351 , 0.04941979, 0.05071914, 0.05098796,
#        0.04211659, 0.05593889, 0.06398138, 0.06008336, 0.0633765 ,
#        0.06342132, 0.06545993, 0.06631123, 0.06404858, 0.06581838,
#        0.07097093, 0.07737803, 0.08091761, 0.08230657, 0.08398675,
#        0.08598057, 0.0853757 , 0.08772796, 0.09556881, 0.09370941,
#        0.08613737, 0.08978898, 0.08539812, 0.08680945, 0.08741433,
#        0.08557731, 0.08080561, 0.08123125, 0.08244098, 0.07654915,
#        0.07146378, 0.07641472, 0.07448811, 0.07753484, 0.08221696,
#        0.08542051, 0.08324747, 0.07966308, 0.0825978 , 0.08143288,
#        0.07401766, 0.07594427, 0.07372643, 0.080716  , 0.07636992])]
# [0.07636992231957127, 0.07596667773981217]

# %%
#utiliser un réseau de neurones récurrent pour prdéire le cours de la bourse #supervised DL

# %%
#converting x_train and y_train into np arrays
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
#x_train.shape[0] for 1st value
# Out:
# (1084, 60)

# %%
#reshaping the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1)) #x_train.shape == 60
x_train.shape
#y_train = np.reshape(y_train, ())
# Out:
# (1084, 60, 1)

# %%
#build the LSTM model

model = Sequential()
#50 nerons
model.add(LSTM(50, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
#25neurons
model.add(Dense(25))
model.add(Dense(1))

# %%
#compile th model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
#training
model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# Epoch 1/1
# 1084/1084 [==============================] - 383s 353ms/step - loss: 4.2507e-04

# %%
#testing dataset creation
#scaled values array from index 1084 to 1144 creation
test_data = scaled_close_data[training_data_len - 60: , :]

#x_test and y_test data sets creation
x_test= []
y_test= close_dataset[training_data_len:, :]

for i in range (60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    #y_test.append()

# %%
#converting data to np array 
x_test = np.array(x_test)

# %%
print(x_test.shape)
#reshaping the data #we need a 3 dimensional shape
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
# Out:
# (285, 60)

# %%
x_test.shape
# Out:
# (285, 60, 1)

# %%
#get the model predicted price values
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions) #unscaling the values

# %%
#model evalutation with the RMSE
rmse = np.sqrt(np.mean(predictions - y_test)**2)
rmse
# Out:
# 1.927946298164234

# %%
#plotting data 
train = close_data[:training_data_len]
valid = close_data[training_data_len:]
valid['Predictions'] = predictions
# Out:
# /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
valid
# Out:
#                  Close  Predictions
# Date
# 2019-07-22   51.805000    51.495911
# 2019-07-23   52.209999    51.593952
# 2019-07-24   52.167500    51.758961
# 2019-07-25   51.755001    51.942242
# 2019-07-26   51.935001    52.080090
# ...                ...          ...
# 2020-08-28  124.807503   115.559944
# 2020-08-31  129.039993   116.237305
# 2020-09-01  134.179993   117.096024
# 2020-09-02  131.399994   118.407021
# 2020-09-03  120.879997   119.491722
#
# [285 rows x 2 columns]

# %%
#data vizualisation
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date')
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Validation', 'Predictions'], loc='lower right')
plt.show()

# %%
#show the valid and predicted prices
valid
# Out:
#                  Close  Predictions
# Date
# 2019-07-22   51.805000    51.495911
# 2019-07-23   52.209999    51.593952
# 2019-07-24   52.167500    51.758961
# 2019-07-25   51.755001    51.942242
# 2019-07-26   51.935001    52.080090
# ...                ...          ...
# 2020-08-28  124.807503   115.559944
# 2020-08-31  129.039993   116.237305
# 2020-09-01  134.179993   117.096024
# 2020-09-02  131.399994   118.407021
# 2020-09-03  120.879997   119.491722
#
# [285 rows x 2 columns]

# %%
#get the quote
apple_quote = web.DataReader('AAPL', data_source='yahoo', start='2015-01-01', end='2018-09-03')
# new dataframe creation
new_df = apple_quote.filter(['Close'])
#get the last 60 days closing price values &convert df to np array
last_60_days = new_df[-60:].values

#data scaling between 0 and 1
last_60_days_scaled = scaler.transform(last_60_days)

#empty list creation
X_test = []
#append the 60 past days
X_test.append(last_60_days_scaled)
#convert to np array
X_test = np.array(X_test)
#reshaping
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

#get predicted scaled price
pred_price = model.predict(X_test)
#unscaling
pred_price = scaler.inverse_transform(pred_price)
print(pred_price)
# Out:
# [[55.531147]]

# %%
apple_quote2 = web.DataReader('AAPL', data_source='yahoo', start='2019-09-03', end='2019-09-03')
print(apple_quote2['Close'])
# Out:
# Date
# 2019-09-03    51.424999
# Name: Close, dtype: float64

# %%
#add AMZN, NFLX, GOOGL, FB and MSFT and follow the pipeline

# %%
#conda install -c conda-forge jupyterthemes
#!pip3 install jupyterthemes
# !pip3 install jupyterthemes==0.16.1
# Out:
# Requirement already satisfied: jupyterthemes==0.16.1 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (0.16.1)
# Requirement already satisfied: jupyter in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from jupyterthemes==0.16.1) (1.0.0)
# Requirement already satisfied: jupyter-core in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from jupyterthemes==0.16.1) (4.6.3)
# Requirement already satisfied: lesscpy>=0.12.0 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from jupyterthemes==0.16.1) (0.14.0)
# Requirement already satisfied: ipykernel in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from jupyter->jupyterthemes==0.16.1) (5.3.4)
# Requirement already satisfied: nbconvert in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from jupyter->jupyterthemes==0.16.1) (5.6.1)
# Requirement already satisfied: qtconsole in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from jupyter->jupyterthemes==0.16.1) (4.7.7)
# Requirement already satisfied: jupyter-console in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from jupyter->jupyterthemes==0.16.1) (6.2.0)
# Requirement already satisfied: notebook in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from jupyter->jupyterthemes==0.16.1) (6.1.1)
# Requirement already satisfied: ipywidgets in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from jupyter->jupyterthemes==0.16.1) (7.5.1)
# Requirement already satisfied: traitlets in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from jupyter-core->jupyterthemes==0.16.1) (4.3.3)
# Requirement already satisfied: ply in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from lesscpy>=0.12.0->jupyterthemes==0.16.1) (3.11)
# Requirement already satisfied: six in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from lesscpy>=0.12.0->jupyterthemes==0.16.1) (1.15.0)
# Requirement already satisfied: tornado>=4.2 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from ipykernel->jupyter->jupyterthemes==0.16.1) (6.0.4)
# Requirement already satisfied: jupyter-client in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from ipykernel->jupyter->jupyterthemes==0.16.1) (6.1.6)
# Requirement already satisfied: ipython>=5.0.0 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from ipykernel->jupyter->jupyterthemes==0.16.1) (7.17.0)
# Requirement already satisfied: jinja2>=2.4 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from nbconvert->jupyter->jupyterthemes==0.16.1) (2.11.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from nbconvert->jupyter->jupyterthemes==0.16.1) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from nbconvert->jupyter->jupyterthemes==0.16.1) (0.8.4)
# Requirement already satisfied: pygments in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from nbconvert->jupyter->jupyterthemes==0.16.1) (2.6.1)
# Requirement already satisfied: testpath in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from nbconvert->jupyter->jupyterthemes==0.16.1) (0.4.4)
# Requirement already satisfied: defusedxml in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from nbconvert->jupyter->jupyterthemes==0.16.1) (0.6.0)
# Requirement already satisfied: bleach in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from nbconvert->jupyter->jupyterthemes==0.16.1) (3.1.5)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from nbconvert->jupyter->jupyterthemes==0.16.1) (1.4.2)
# Requirement already satisfied: nbformat>=4.4 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from nbconvert->jupyter->jupyterthemes==0.16.1) (5.0.7)
# Requirement already satisfied: ipython-genutils in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from qtconsole->jupyter->jupyterthemes==0.16.1) (0.2.0)
# Requirement already satisfied: qtpy in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from qtconsole->jupyter->jupyterthemes==0.16.1) (1.9.0)
# Requirement already satisfied: pyzmq>=17.1 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from qtconsole->jupyter->jupyterthemes==0.16.1) (19.0.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from jupyter-console->jupyter->jupyterthemes==0.16.1) (3.0.5)
# Requirement already satisfied: argon2-cffi in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from notebook->jupyter->jupyterthemes==0.16.1) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from notebook->jupyter->jupyterthemes==0.16.1) (0.8.3)
# Requirement already satisfied: prometheus-client in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from notebook->jupyter->jupyterthemes==0.16.1) (0.8.0)
# Requirement already satisfied: Send2Trash in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from notebook->jupyter->jupyterthemes==0.16.1) (1.5.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from ipywidgets->jupyter->jupyterthemes==0.16.1) (3.5.1)
# Requirement already satisfied: decorator in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from traitlets->jupyter-core->jupyterthemes==0.16.1) (4.4.2)
# Requirement already satisfied: python-dateutil>=2.1 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from jupyter-client->ipykernel->jupyter->jupyterthemes==0.16.1) (2.8.1)
# Requirement already satisfied: setuptools>=18.5 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyterthemes==0.16.1) (49.2.1.post20200807)
# Requirement already satisfied: pickleshare in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyterthemes==0.16.1) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyterthemes==0.16.1) (0.17.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyterthemes==0.16.1) (4.8.0)
# Requirement already satisfied: backcall in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyterthemes==0.16.1) (0.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from jinja2>=2.4->nbconvert->jupyter->jupyterthemes==0.16.1) (1.1.1)
# Requirement already satisfied: packaging in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from bleach->nbconvert->jupyter->jupyterthemes==0.16.1) (20.4)
# Requirement already satisfied: webencodings in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from bleach->nbconvert->jupyter->jupyterthemes==0.16.1) (0.5.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from nbformat>=4.4->nbconvert->jupyter->jupyterthemes==0.16.1) (3.2.0)
# Requirement already satisfied: wcwidth in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->jupyterthemes==0.16.1) (0.2.5)
# Requirement already satisfied: cffi>=1.0.0 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from argon2-cffi->notebook->jupyter->jupyterthemes==0.16.1) (1.14.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->jupyter->jupyterthemes==0.16.1) (0.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.0.0->ipykernel->jupyter->jupyterthemes==0.16.1) (0.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from packaging->bleach->nbconvert->jupyter->jupyterthemes==0.16.1) (2.4.7)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter->jupyterthemes==0.16.1) (0.16.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter->jupyterthemes==0.16.1) (19.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter->jupyterthemes==0.16.1) (1.7.0)
# Requirement already satisfied: pycparser in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->jupyterthemes==0.16.1) (2.20)
# Requirement already satisfied: zipp>=0.5 in /home/jasminelabeille/anaconda3/envs/timeSeries/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter->jupyterthemes==0.16.1) (3.1.0)

# %%
# !jt -r  # + refresh the notebook #to restore back
# Out:
# Reset css and font defaults in:
# /home/jasminelabeille/.jupyter/custom &
# /home/jasminelabeille/.local/share/jupyter/nbextensions

# %%
# !jt -l #list of themes
# Out:
# Available Themes:
#    chesterish
#    grade3
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t onedork  # + refresh the notebook # to switch into dark theme
#changing the font:
#!jt -t solarizedd -f fira -fs 115
#adjusting cell width:
#!jt -t chesterish -cellw 90% -lineh 170
#cursor width and colour:
#!jt -t oceans16 -cursc r -cursw 5
#!jt -r  # + refresh the notebook #to restore back

# %%
#changing the font:
#!jt -t solarizedd -f fira -fs 115

# %%
#adjusting cell width:
#!jt -t chesterish -cellw 90% -lineh 170

# %%
#cursor width and colour:
#!jt -t oceans16 -cursc r -cursw 5

# %% [markdown]
# Plotting With The Theme
#
# The jupyterthemes library also allows you to make appealing visualisation with its submodule jtplot. Import the module and use its style() method to change figure properties.
#
# `#import the module
# from jupyterthemes import jtplot`
#
# the style() method can be used to beautify your visualisation

# %%
# another method with import

#from jupyterthemes import get_themes
#from jupyterthemes.styles import set_rb_theme
